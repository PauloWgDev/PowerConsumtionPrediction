# %% [markdown]
# # Load SOMC_AC

# %%
import numpy as np
import pandas as pd

# %%
# Load the CSV file
path = "../Raw Data/SOMC_AC_20240505_20250505_3600.csv"
df = pd.read_csv(path)

df.head(5)
# Out:
#   toll_booth      gantry            data_time  ac_a_current  ac_b_current  \
# 0         泰山  01F-000.5N  2024-06-01 00:00:05           0.1           0.2
# 1         泰山  01F-000.5S  2024-06-01 00:00:05           0.1           2.0
# 2         泰山  01F-001.7S  2024-06-01 00:00:05           0.1           1.0
# 3         泰山  01F-002.9S  2024-06-01 00:00:05           0.1           0.2
# 4         泰山  01F-006.1S  2024-06-01 00:00:05           1.9           0.2
#
#    rs485_temperature  mains_power_220_current  mains_power_l1_voltage  \
# 0               16.4                      5.6                    79.3
# 1               22.1                      7.1                   115.0
# 2               19.6                      8.8                   115.6
# 3               21.4                      8.7                   117.1
# 4               17.7                     11.3                   116.7
#
#    mains_power_l2_voltage  smr_dc_current  smr_dc_voltage
# 0                   155.3            36.0            26.7
# 1                   122.4            35.3            26.7
# 2                   115.7            55.5            26.8
# 3                   117.2            57.7            26.8
# 4                   118.4            66.4            26.8

# %% [markdown]
# # Filters the DataFrame to return only rows where the toll_booth matches the given name

# %%
def get_toll_booth_data(df, toll_booth_name):
    return df[df['toll_booth'] == toll_booth_name]

# %%
taishan_df = get_toll_booth_data(df, "泰山")
taishan_df.tail(5)
# Out:
#         toll_booth      gantry            data_time  ac_a_current  \
# 1703394         泰山  01H-033.3N  2025-05-04 23:00:30           1.7
# 1703395         泰山  01H-033.4S  2025-05-04 23:00:30           1.6
# 1703396         泰山  01H-044.7N  2025-05-04 23:00:30           1.4
# 1703397         泰山  01H-044.7S  2025-05-04 23:00:30           0.2
# 1703399         泰山  01H-057.9S  2025-05-04 23:00:32           1.5
#
#          ac_b_current  rs485_temperature  mains_power_220_current  \
# 1703394           0.1               19.9                      7.1
# 1703395           0.1               20.6                      7.2
# 1703396           0.1               18.9                      6.9
# 1703397           0.1               22.8                      6.0
# 1703399           0.1               17.6                      7.4
#
#          mains_power_l1_voltage  mains_power_l2_voltage  smr_dc_current  \
# 1703394                   116.6                   116.4            36.8
# 1703395                   115.9                   115.9            36.8
# 1703396                   116.2                   116.1            38.6
# 1703397                   114.5                   114.4            38.9
# 1703399                   115.9                   115.6            40.8
#
#          smr_dc_voltage
# 1703394            26.4
# 1703395            26.4
# 1703396            26.8
# 1703397            26.7
# 1703399            26.7

# %% [markdown]
# ## Aggregate reading by Day

# %%
# Convert to datetime
df['data_time'] = pd.to_datetime(df['data_time'])

# Extract date
df['date'] = df['data_time'].dt.date

# Group by date (optional: add 'toll_booth' or 'gantry' for finer granularity)
daily_agg = df.groupby(['toll_booth', 'gantry', 'date']).agg({
    'ac_a_current': 'mean',
    'ac_b_current': 'mean',
    'rs485_temperature': 'mean',
    'mains_power_220_current': 'mean',
    'mains_power_l1_voltage': 'mean',
    'mains_power_l2_voltage': 'mean',
    'smr_dc_current': 'mean',
    'smr_dc_voltage': 'mean'
}).reset_index()

# %%
daily_agg.head(10)
# Out:
#   toll_booth      gantry        date  ac_a_current  ac_b_current  \
# 0         后里  01F-104.5N  2024-06-01      0.100000      2.095833
# 1         后里  01F-104.5N  2024-06-02      1.608333      0.100000
# 2         后里  01F-104.5N  2024-06-03      1.579167      0.100000
# 3         后里  01F-104.5N  2024-06-04      0.204167      1.516667
# 4         后里  01F-104.5N  2024-06-05      1.604167      0.100000
# 5         后里  01F-104.5N  2024-06-06      0.100000      1.612500
# 6         后里  01F-104.5N  2024-06-07      1.687500      0.100000
# 7         后里  01F-104.5N  2024-06-08      0.100000      2.029167
# 8         后里  01F-104.5N  2024-06-09      1.854167      0.100000
# 9         后里  01F-104.5N  2024-06-10      2.158333      0.100000
#
#    rs485_temperature  mains_power_220_current  mains_power_l1_voltage  \
# 0          18.820833                11.554167              114.704167
# 1          18.158333                10.900000              116.066667
# 2          18.308333                10.737500              116.391667
# 3          17.987500                10.845833              114.833333
# 4          17.987500                10.866667              114.891667
# 5          17.629167                10.850000              115.295833
# 6          18.308333                11.070833              115.004167
# 7          17.795833                11.508333              114.270833
# 8          18.612500                11.145833              116.245833
# 9          19.195833                11.516667              114.854167
#
#    mains_power_l2_voltage  smr_dc_current  smr_dc_voltage
# 0              115.029167       66.220833       26.758333
# 1              116.412500       66.137500       26.750000
# 2              116.704167       66.120833       26.762500
# 3              115.083333       65.708333       26.758333
# 4              115.208333       65.408333       26.758333
# 5              115.579167       65.804167       26.750000
# 6              115.345833       66.116667       26.754167
# 7              114.554167       66.591667       26.766667
# 8              116.608333       66.204167       26.741667
# 9              115.241667       66.308333       26.733333

# %% [markdown]
# # Get all toll booths

# %%
unique_toll_booths = daily_agg['toll_booth'].unique()
print(unique_toll_booths)
# Out:
# ['后里' '員林' '新市' '楊梅' '樹林' '泰山' '田寮']

# %% [markdown]
# # Toll Booths:
#
# ['后里' '員林' '新市' '楊梅' '樹林' '泰山' '田寮']
#
# - 后里
# - 員林
# - 新市
# - 楊梅
# - 樹林
# - 泰山
# - 田寮

# %% [markdown]
# # Get The range of time on the Data Set

# %%
# Convert 'date' column to datetime if it's not already
daily_agg['date'] = pd.to_datetime(daily_agg['date'])

# Get the min and max dates
start_date = daily_agg['date'].min()
end_date = daily_agg['date'].max()

print(f"Dataset covers from {start_date.date()} to {end_date.date()}")
# Out:
# Dataset covers from 2024-06-01 to 2025-05-04

# %% [markdown]
# # Export aggregated Reading as csv

# %%
output_path = "../Clean Data/aggregated_day_SOMC_AC_20240505_20250505_3600.csv"
daily_agg.to_csv(output_path, index=False)

# %% [markdown]
# # Electricity Data of the toll station phase 1

# %%
path = "../Raw Data/Electricity of the toll station-phase 1 simplified.csv"

electricity_toll_station_df = pd.read_csv(path, skiprows=1)

electricity_toll_station_df.head(5)
# Out:
#   Location ID   Latitude   Longitude  Equipment Lane Count  Lane Count  \
# 0    01F0233N  25.073019  121.530703                   5.0         4.0
# 1    01F0233N  25.073019  121.530703                   5.0         4.0
# 2    01F0233N  25.073019  121.530703                   5.0         4.0
# 3    01F0233N  25.073019  121.530703                   5.0         4.0
# 4    01F0256N  25.078067  121.509106                   6.0         4.0
#
#   Electricity Number  Billing Month  Electricity Consumption (kWh)  \
# 0    00-03-9910-00-3          11307                           2453
# 1    00-03-9910-00-3          11309                           2672
# 2    00-03-9910-00-3          11311                           2605
# 3    00-03-9910-00-3          11401                           2294
# 4    00-21-9981-00-1          11305                           2645
#
#   Feeder Line Category Power Outage Group  ...  Lighting Usage Category  \
# 0                 ZQ55                  C  ...                      B21
# 1                 ZQ55                  C  ...                      B21
# 2                 ZQ55                  C  ...                      B21
# 3                 ZQ55                  C  ...                      B21
# 4                 SA39                  A  ...                      B21
#
#    Number of Usage Days Last Year (Second Half)  Billed kWh - Regular (Peak)  \
# 0                                            60                         2453
# 1                                            61                         2672
# 2                                            63                         2605
# 3                                            61                         2294
# 4                                            61                         2645
#
#   Number of Usage Days Same Period Last Year Average Electricity Consumption  \
# 0                                         61                            2453
# 1                                         60                            2672
# 2                                         61                            2605
# 3                                         63                            2294
# 4                                         56                             983
#
#   Electricity Usage Same Period Last Year  \
# 0                                    2457
# 1                                    2472
# 2                                    2375
# 3                                    2573
# 4                                    2213
#
#   Electricity Usage Last Year (Second Half) Number of Usage Days This Period  \
# 0                                      2472                               59
# 1                                      2375                               63
# 2                                      2573                               62
# 3                                      2418                               58
# 4                                      2454                               66
#
#   Unnamed: 21 Maintenance Station
# 0  01F-023.3N                北區泰山
# 1  01F-023.3N                北區泰山
# 2  01F-023.3N                北區泰山
# 3  01F-023.3N                北區泰山
# 4  01F-025.6N                北區泰山
#
# [5 rows x 23 columns]

# %%
# Get all unique Maintenance Stations

unique_stations = electricity_toll_station_df['Maintenance Station'].unique()
print(unique_stations)
# Out:
# ['北區泰山' '北區樹林' '北區楊梅' '行政部門' '中區后里' '中區員林' '南區新市' '南區田寮' 'IT機房']

# %% [markdown]
# # Normalize the Mantainance Station names

# %%
# Define allowed station names (as per your target list)
valid_stations = ['后里', '員林', '新市', '楊梅', '樹林', '泰山', '田寮']

# Function to extract matching station name
def clean_station_name(name):
    for station in valid_stations:
        if station in name:
            return station
    return None  # Filter out unwanted entries

# Apply the cleaning
electricity_toll_station_df['Station'] = electricity_toll_station_df['Maintenance Station'].apply(clean_station_name)

# Drop rows with None (i.e., unmatched stations like 行政部門, IT機房)
electricity_toll_station_df = electricity_toll_station_df.dropna(subset=['Station'])

# Optional: check unique cleaned names
print(electricity_toll_station_df['Station'].unique())
# Out:
# ['泰山' '樹林' '楊梅' '后里' '員林' '新市' '田寮']

# %% [markdown]
# # Normalize Dates

# %%
# Function to convert Minguo date (e.g. 11307 or 1130624) to Gregorian YYYY-MM or YYYY-MM-DD
def convert_minguo_date(value):
    if pd.isna(value):
        return None
    value_str = str(int(value))
    if len(value_str) == 5:  # e.g., 11307 → YYYY-MM
        year = int(value_str[:3]) + 1911
        month = int(value_str[3:])
        return f"{year:04d}-{month:02d}"
    elif len(value_str) == 7:  # e.g., 1130624 → YYYY-MM-DD
        year = int(value_str[:3]) + 1911
        month = int(value_str[3:5])
        day = int(value_str[5:])
        return f"{year:04d}-{month:02d}-{day:02d}"
    else:
        return None

# %%
# Columns with Minguo dates
minguo_date_columns = [
    'Billing Month', 'Billing Period (Start)', 'Billing Period (End)', 'Billing Date'
]

# Apply conversion
for col in minguo_date_columns:
    electricity_toll_station_df[col] = electricity_toll_station_df[col].apply(convert_minguo_date)

# Preview result
print(electricity_toll_station_df[[col for col in minguo_date_columns]].head())
# Out:
#   Billing Month Billing Period (Start) Billing Period (End) Billing Date
# 0       2024-07             2024-04-29           2024-06-26   2024-07-03
# 1       2024-09             2024-06-27           2024-08-28   2024-09-04
# 2       2024-11             2024-08-29           2024-10-29   2024-11-05
# 3       2025-01             2024-10-30           2024-12-26   2025-01-06
# 4       2024-05             2024-02-27           2024-05-02   2024-05-09

# %%
electricity_toll_station_df.head()
# Out:
#   Location ID   Latitude   Longitude  Equipment Lane Count  Lane Count  \
# 0    01F0233N  25.073019  121.530703                   5.0         4.0
# 1    01F0233N  25.073019  121.530703                   5.0         4.0
# 2    01F0233N  25.073019  121.530703                   5.0         4.0
# 3    01F0233N  25.073019  121.530703                   5.0         4.0
# 4    01F0256N  25.078067  121.509106                   6.0         4.0
#
#   Electricity Number Billing Month  Electricity Consumption (kWh)  \
# 0    00-03-9910-00-3       2024-07                           2453
# 1    00-03-9910-00-3       2024-09                           2672
# 2    00-03-9910-00-3       2024-11                           2605
# 3    00-03-9910-00-3       2025-01                           2294
# 4    00-21-9981-00-1       2024-05                           2645
#
#   Feeder Line Category Power Outage Group  ...  \
# 0                 ZQ55                  C  ...
# 1                 ZQ55                  C  ...
# 2                 ZQ55                  C  ...
# 3                 ZQ55                  C  ...
# 4                 SA39                  A  ...
#
#   Number of Usage Days Last Year (Second Half) Billed kWh - Regular (Peak)  \
# 0                                           60                        2453
# 1                                           61                        2672
# 2                                           63                        2605
# 3                                           61                        2294
# 4                                           61                        2645
#
#   Number of Usage Days Same Period Last Year Average Electricity Consumption  \
# 0                                         61                            2453
# 1                                         60                            2672
# 2                                         61                            2605
# 3                                         63                            2294
# 4                                         56                             983
#
#   Electricity Usage Same Period Last Year  \
# 0                                    2457
# 1                                    2472
# 2                                    2375
# 3                                    2573
# 4                                    2213
#
#   Electricity Usage Last Year (Second Half) Number of Usage Days This Period  \
# 0                                      2472                               59
# 1                                      2375                               63
# 2                                      2573                               62
# 3                                      2418                               58
# 4                                      2454                               66
#
#   Unnamed: 21 Maintenance Station Station
# 0  01F-023.3N                北區泰山      泰山
# 1  01F-023.3N                北區泰山      泰山
# 2  01F-023.3N                北區泰山      泰山
# 3  01F-023.3N                北區泰山      泰山
# 4  01F-025.6N                北區泰山      泰山
#
# [5 rows x 24 columns]

# %% [markdown]
# # Export Electricity Data of toll

# %%
output_path = "../Clean Data/aggregated_day_SOMC_AC_20240505_20250505_3600.csv"
electricity_toll_station_df.to_csv(output_path, index=False)
